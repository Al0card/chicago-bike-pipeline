# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/trips_clean_202501.csv")

# %%
print(df.columns)
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'member_casual', 'duration_seconds', 'trip_date',
#        'trip_year', 'trip_month', 'trip_weekday', 'trip_hour', 'source_batch'],
#       dtype='str')

# %%
print(df.shape)
# Out:
# (138689, 16)

# %%
station_cols = ['start_station_name', 'start_station_id', 'end_station_name','end_station_id']
for col in station_cols:
    print(col  ,df[col].isnull().sum())
# Out:
# start_station_name 22852
# start_station_id 22852
# end_station_name 24073
# end_station_id 24073

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 138689 entries, 0 to 138688
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             138689 non-null  str
#  1   rideable_type       138689 non-null  str
#  2   started_at          138689 non-null  str
#  3   ended_at            138689 non-null  str
#  4   start_station_name  115837 non-null  str
#  5   start_station_id    115837 non-null  str
#  6   end_station_name    114616 non-null  str
#  7   end_station_id      114616 non-null  str
#  8   member_casual       138689 non-null  str
#  9   duration_seconds    138689 non-null  float64
#  10  trip_date           138689 non-null  str
#  11  trip_year           138689 non-null  int64
#  12  trip_month          138689 non-null  int64
#  13  trip_weekday        138689 non-null  str
#  14  trip_hour           138689 non-null  int64
#  15  source_batch        138689 non-null  int64
# dtypes: float64(1), int64(4), str(11)
# memory usage: 16.9 MB

# %%
generated_cols = ['duration_seconds', 'trip_date', 'trip_year', 'trip_month', 'trip_weekday', 'trip_hour']
for col in generated_cols:
    print(col, df[col].isnull().sum())
# Out:
# duration_seconds 0
# trip_date 0
# trip_year 0
# trip_month 0
# trip_weekday 0
# trip_hour 0

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  7569BC890583FCD7   classic_bike  2025-01-21 17:23:54.538
# 1  013609308856B7FC  electric_bike  2025-01-11 15:44:06.795
# 2  EACACD3CE0607C0D   classic_bike  2025-01-02 15:16:27.730
# 3  EAA2485BA64710D3   classic_bike  2025-01-23 08:49:05.814
# 4  7F8BE2471C7F746B  electric_bike  2025-01-16 08:38:32.338
#
#                   ended_at            start_station_name start_station_id  \
# 0  2025-01-21 17:37:52.015     Wacker Dr & Washington St     KA1503000072
# 1  2025-01-11 15:49:11.139   Halsted St & Wrightwood Ave     TA1309000061
# 2  2025-01-02 15:28:03.230  Southport Ave & Waveland Ave            13235
# 3  2025-01-23 08:52:40.047  Southport Ave & Waveland Ave            13235
# 4  2025-01-16 08:41:06.767  Southport Ave & Waveland Ave            13235
#
#             end_station_name end_station_id member_casual  duration_seconds  \
# 0       McClurg Ct & Ohio St   TA1306000029        member           837.477
# 1   Racine Ave & Belmont Ave   TA1308000019        member           304.344
# 2    Broadway & Cornelia Ave          13278        member           695.500
# 3  Southport Ave & Roscoe St          13071        member           214.233
# 4  Southport Ave & Roscoe St          13071        member           154.429
#
#     trip_date  trip_year  trip_month trip_weekday  trip_hour  source_batch
# 0  2025-01-21       2025           1      Tuesday         17        202501
# 1  2025-01-11       2025           1     Saturday         15        202501
# 2  2025-01-02       2025           1     Thursday         15        202501
# 3  2025-01-23       2025           1     Thursday          8        202501
# 4  2025-01-16       2025           1     Thursday          8        202501
